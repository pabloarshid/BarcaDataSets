# %%
# %matplotlib inline
import os
import re
import pandas as pd
import datetime as dt
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16, 10]
plt.rcParams['font.size'] = 14
import seaborn as sns
import warnings
fig = plt.gcf()
fig.set_size_inches( 16, 10)

# %%
busstops= pd.read_csv("bus_stops.csv")
transports = pd.read_csv("transports.csv")
accidents = pd.read_csv("accidents_2017.csv")
population = pd.read_csv("population.csv")
births = pd.read_csv("births.csv")
deaths = pd.read_csv("deaths.csv")
airq= pd.read_csv("air_quality_Nov2017.csv")
airstat= pd.read_csv("air_stations_Nov2017.csv")
immbynat = pd.read_csv("immigrants_by_nationality.csv")
immbyage = pd.read_csv("immigrants_emigrants_by_age.csv")
immbyd1 = pd.read_csv("immigrants_emigrants_by_destination.csv")
immbyd2 = pd.read_csv("immigrants_emigrants_by_destination2.csv")
immbysex = pd.read_csv("immigrants_emigrants_by_sex.csv")

freqnames = pd.read_csv("most_frequent_names.csv")
freqbabynames = pd.read_csv("most_frequent_baby_names.csv")
unemployement = pd.read_csv("unemployment.csv")

# %%
populationbyyear = population.groupby(["Year","Gender"], as_index=False).sum()
populationbyD = population.groupby(["Year","District.Name"], as_index=False).sum()

# %%
ax = sns.barplot(x = "Year", y = "Number", hue = "Gender", data = populationbyyear)
ax.set(ylim=(700000, 900000))
# Out:
# [(700000, 900000)]

# %%
ax = sns.barplot(x = "Year", y = "Number", hue = "District.Name", data = populationbyD)
ax.set(ylim=(50000, 300000))
# Out:
# [(50000, 300000)]

# %%
accbymonthcts = accidents.groupby('Weekday').Hour.value_counts()
accbymonthcts.to_frame().Hour
accbymonthcts = accbymonthcts.reset_index(level=["Weekday"])
accbymonthcts = accbymonthcts.rename(columns = {'Hour':'Count'})
accbymonthcts.reset_index(level=0, inplace=True)

sns.catplot("Weekday","Count", "Hour", data = accbymonthcts, kind = "bar", palette="muted",height=8.27, aspect=11.7/8.27)
# Out:
# Weekday    Hour
# Friday     13      146
#            15      141
#            14      130
#            16      120
#            17      118
#            12      112
#            18      109
#            8       102
#            9       102
#            19      101
#            20       86
#            11       81
#            10       80
#            21       79
#            7        57
#            22       51
#            23       40
#            0        27
#            6        27
#            1        18
#            2        17
#            5         9
#            4         5
#            3         3
# Monday     9       115
#            16      107
#            15      104
#            14      102
#            18      102
#            8       101
#                   ...
# Tuesday    6        23
#            1        12
#            5         9
#            4         7
#            3         5
#            2         4
# Wednesday  8       125
#            9       119
#            13      119
#            14      117
#            18      112
#            17      108
#            19      108
#            16      101
#            15       99
#            20       99
#            12       89
#            10       88
#            11       80
#            21       79
#            22       53
#            7        46
#            23       25
#            0        20
#            5        17
#            6        16
#            1        15
#            2         7
#            3         4
#            4         4
# Name: Hour, Length: 168, dtype: int64

# %%
accbydistcts = accidents.groupby('District Name').Hour.value_counts()
accbydistcts.to_frame().Hour
accbydistcts = accbydistcts.reset_index(level=["District Name"])
accbydistcts = accbydistcts.rename(columns = {'Hour':'Count'})
accbydistcts.reset_index(level=0, inplace=True)

sns.catplot("District Name","Count", "Hour", data = accbydistcts, kind = "bar", palette="muted",height=8.27, aspect=20.7/8.27)
# Out:
# District Name        Hour
# Ciutat Vella         18       46
#                      17       42
#                      12       40
#                      15       40
#                      14       38
#                      13       34
#                      16       34
#                      21       34
#                      19       33
#                      11       32
#                      9        29
#                      10       27
#                      20       25
#                      22       25
#                      8        20
#                      23       18
#                      7        17
#                      0        14
#                      5        13
#                      1        12
#                      6        12
#                      4         7
#                      2         4
#                      3         4
# Eixample             13      235
#                      14      231
#                      15      204
#                      12      198
#                      16      197
#                      19      186
#                             ...
# Sarrià-Sant Gervasi  21       50
#                      11       49
#                      10       47
#                      7        34
#                      22       34
#                      23       27
#                      0        20
#                      6        12
#                      1         9
#                      2         9
#                      4         9
#                      5         8
#                      3         3
# Unknown              9         3
#                      14        3
#                      17        3
#                      7         2
#                      8         2
#                      12        2
#                      19        2
#                      2         1
#                      6         1
#                      10        1
#                      11        1
#                      13        1
#                      15        1
#                      16        1
#                      18        1
#                      21        1
#                      22        1
# Name: Hour, Length: 257, dtype: int64

# %%
accEix = accidents[accidents["District Name"] == "Eixample"]
accEix["Neighborhood Name"].unique()

accinEix = accEix.groupby('Neighborhood Name').Hour.value_counts()
accinEix.to_frame().Hour
accinEix = accinEix.reset_index(level=["Neighborhood Name"])
accinEix = accinEix.rename(columns = {'Hour':'Count'})
accinEix.reset_index(level=0, inplace=True)


sns.catplot("Neighborhood Name","Count", "Hour", data = accinEix, kind = "bar", palette="muted",height=8.27, aspect=20.7/8.27)
# Out:
# array(['Sant Antoni', "la Nova Esquerra de l'Eixample",
#        'la Sagrada Família', "la Dreta de l'Eixample",
#        "l'Antiga Esquerra de l'Eixample", 'el Fort Pienc'], dtype=object)
# Neighborhood Name               Hour
# Sant Antoni                     13      21
#                                 15      18
#                                 21      18
#                                 19      16
#                                 9       15
#                                 18      15
#                                 11      14
#                                 14      14
#                                 20      13
#                                 8       12
#                                 17      11
#                                 16      10
#                                 22      10
#                                 0        7
#                                 10       7
#                                 12       7
#                                 7        5
#                                 6        4
#                                 23       4
#                                 1        3
#                                 4        3
#                                 5        3
#                                 3        2
#                                 2        1
# el Fort Pienc                   14      26
#                                 12      24
#                                 15      23
#                                 18      21
#                                 19      19
#                                 9       18
#                                         ..
# la Nova Esquerra de l'Eixample  0        3
#                                 1        3
#                                 2        2
#                                 3        2
#                                 4        2
#                                 5        2
# la Sagrada Família              13      35
#                                 9       32
#                                 16      26
#                                 8       25
#                                 12      25
#                                 17      23
#                                 20      23
#                                 15      21
#                                 10      19
#                                 18      19
#                                 14      18
#                                 22      18
#                                 19      16
#                                 7       14
#                                 11      14
#                                 23      14
#                                 21      11
#                                 0        7
#                                 5        4
#                                 6        4
#                                 1        3
#                                 3        3
#                                 4        2
#                                 2        1
# Name: Hour, Length: 142, dtype: int64

# %%
populationbyD
# Out:
#     Year        District.Name  District.Code  Neighborhood.Code  Number
# 0   2013         Ciutat Vella            768               1920  103339
# 1   2013             Eixample           2304               8640  264780
# 2   2013               Gràcia           5760              28800  120949
# 3   2013       Horta-Guinardó          14784              80256  167743
# 4   2013            Les Corts           2304              11520   81640
# 5   2013           Nou Barris          19968             124800  165748
# 6   2013          Sant Andreu          12096              80640  146846
# 7   2013           Sant Martí          19200             131520  232826
# 8   2013       Sants-Montjuïc           4608              22272  182685
# 9   2013  Sarrià-Sant Gervasi           5760              28224  145266
# 10  2014         Ciutat Vella            768               1920  100685
# 11  2014             Eixample           2304               8640  263565
# 12  2014               Gràcia           5760              28800  120273
# 13  2014       Horta-Guinardó          14784              80256  166950
# 14  2014            Les Corts           2304              11520   81200
# 15  2014           Nou Barris          19968             124800  164516
# 16  2014          Sant Andreu          12096              80640  145983
# 17  2014           Sant Martí          19200             131520  232629
# 18  2014       Sants-Montjuïc           4608              22272  180824
# 19  2014  Sarrià-Sant Gervasi           5760              28224  145761
# 20  2015         Ciutat Vella            768               1920  100115
# 21  2015             Eixample           2304               8640  263558
# 22  2015               Gràcia           5760              28800  120401
# 23  2015       Horta-Guinardó          14784              80256  166559
# 24  2015            Les Corts           2304              11520   81530
# 25  2015           Nou Barris          19968             124800  164648
# 26  2015          Sant Andreu          12096              80640  146494
# 27  2015           Sant Martí          19200             131520  233659
# 28  2015       Sants-Montjuïc           4608              22272  180757
# 29  2015  Sarrià-Sant Gervasi           5760              28224  146834
# 30  2016         Ciutat Vella            768               1920  100070
# 31  2016             Eixample           2304               8640  264305
# 32  2016               Gràcia           5760              28800  120918
# 33  2016       Horta-Guinardó          14784              80256  167268
# 34  2016            Les Corts           2304              11520   81642
# 35  2016           Nou Barris          19968             124800  164881
# 36  2016          Sant Andreu          12096              80640  146731
# 37  2016           Sant Martí          19200             131520  233928
# 38  2016       Sants-Montjuïc           4608              22272  180977
# 39  2016  Sarrià-Sant Gervasi           5760              28224  148026
# 40  2017         Ciutat Vella            768               1920  101387
# 41  2017             Eixample           2304               8640  266416
# 42  2017               Gràcia           5760              28800  121347
# 43  2017       Horta-Guinardó          14784              80256  168751
# 44  2017            Les Corts           2304              11520   82033
# 45  2017           Nou Barris          19968             124800  166579
# 46  2017          Sant Andreu          12096              80640  147594
# 47  2017           Sant Martí          19200             131520  235513
# 48  2017       Sants-Montjuïc           4608              22272  181910
# 49  2017  Sarrià-Sant Gervasi           5760              28224  149279

# %%
sns.catplot("District.Name","Number", "Year", data = populationbyD, kind = "bar", palette="muted",height=8.27, aspect=20.7/8.27)

# %%
popex = population[population["District.Name"] == "Eixample"]

populationEix = popex.groupby(["Year","Neighborhood.Name"], as_index=False).sum()
sns.catplot("Neighborhood.Name","Number", "Year", data = populationEix, kind = "bar", palette="muted",height=8.27, aspect=20.7/8.27)

# %%
transports
# Out:
#      Code         Transport  Longitude   Latitude  \
# 0    K001       Underground   2.119370  41.399203
# 1    K001       Underground   2.135427  41.397791
# 2    K001       Underground   2.185391  41.451492
# 3    K001       Underground   2.174473  41.460889
# 4    K001       Underground   2.168588  41.387200
# 5    K001       Underground   2.168507  41.387706
# 6    K001       Underground   2.118998  41.398967
# 7    K001       Underground   2.083994  41.362753
# 8    K001       Underground   2.142987  41.424923
# 9    K002     Railway (FGC)   2.158326  41.392331
# 10   K001       Underground   2.100302  41.362977
# 11   K001       Underground   2.179581  41.400180
# 12   K001       Underground   2.153966  41.379070
# 13   K001       Underground   2.168735  41.389295
# 14   K001       Underground   2.161228  41.430042
# 15   K011              Tram   2.098896  41.376486
# 16   K001       Underground   2.133190  41.373293
# 17   K001       Underground   2.145478  41.378565
# 18   K001       Underground   2.147798  41.434855
# 19   K001       Underground   2.148557  41.435325
# 20   K001       Underground   2.215909  41.411740
# 21   K001       Underground   2.163252  41.385015
# 22   K011              Tram   2.197653  41.411242
# 23   K011              Tram   2.115012  41.380480
# 24   K011              Tram   2.106023  41.376071
# 25   K011              Tram   2.222916  41.430456
# 26   K011              Tram   2.219829  41.411777
# 27   K011              Tram   2.230412  41.423854
# 28   K011              Tram   2.062227  41.360383
# 29   K008  Maritime station   2.182868  41.370929
# ..    ...               ...        ...        ...
# 621  K001       Underground   2.160499  41.395422
# 622  K001       Underground   2.186242  41.420960
# 623  K001       Underground   2.155126  41.424597
# 624  K001       Underground   2.182557  41.407338
# 625  K001       Underground   2.117108  41.368594
# 626  K001       Underground   2.175019  41.390021
# 627  K001       Underground   2.103931  41.368184
# 628  K001       Underground   2.199663  41.449896
# 629  K001       Underground   2.158936  41.374870
# 630  K001       Underground   2.136549  41.382673
# 631  K001       Underground   2.140979  41.417205
# 632  K002     Railway (FGC)   2.034689  41.357711
# 633  K002     Railway (FGC)   2.068427  41.351845
# 634  K002     Railway (FGC)   2.012394  41.388104
# 635  K011              Tram   2.069961  41.368430
# 636  K001       Underground   2.158998  41.382457
# 637  K001       Underground   2.187227  41.421981
# 638  K001       Underground   2.106409  41.344720
# 639  K001       Underground   2.128698  41.368443
# 640  K001       Underground   2.134031  41.373543
# 641  K004     Airport train   2.193312  41.435959
# 642  K001       Underground   2.157956  41.392909
# 643  K001       Underground   2.187148  41.409242
# 644  K001       Underground   2.133647  41.372953
# 645  K001       Underground   2.154913  41.379656
# 646  K002     Railway (FGC)   2.118998  41.398967
# 647  K008  Maritime station   2.175248  41.352808
# 648  K008  Maritime station   2.174767  41.350955
# 649  K002     Railway (FGC)   2.131188  41.397617
# 650  K001       Underground   2.158822  41.375220
#
#                                                Station        District.Name  \
# 0    FGC (L6) - REINA ELISENDA (Sortida Duquesa d'O...  Sarrià-Sant Gervasi
# 1                              FGC (L6) - LA BONANOVA-  Sarrià-Sant Gervasi
# 2        METRO (L11) - CASA DE L'AIGUA (C. Vila-Real)-           Nou Barris
# 3      METRO (L11) - CIUTAT MERIDIANA (C. Pedraforca)-           Nou Barris
# 4           METRO (L1) - CATALUNYA (Rda. Universitat)-             Eixample
# 5        METRO (L1) - CATALUNYA (Rambla de Catalunya)-             Eixample
# 6                           FGC (L6) - REINA ELISENDA-  Sarrià-Sant Gervasi
# 7                          METRO (L5) - SANT ILDEFONS-                  NaN
# 8    METRO (L3, L5) - VALL D'HEBRON (C. de les Bass...       Horta-Guinardó
# 9                     FGC - PROVENÇA (C. de Provença)-             Eixample
# 10                  METRO (L1) - RAMBLA JUST OLIVERAS-                  NaN
# 11          METRO (L2) - MONUMENTAL (C. de la Marina)-             Eixample
# 12             METRO (L1) - ROCAFORT (C. de Rocafort)-             Eixample
# 13     METRO (L2) - PASSEIG DE GRÀCIA (Pg. de Gràcia)-             Eixample
# 14                 METRO (L5) - HORTA (Pl. d'Eivissa)-       Horta-Guinardó
# 15                 TRAMVIA (T1,T2,T3) - CA N'OLIVERES-                  NaN
# 16   METRO (L1) - MERCAT NOU (C. d'Antoni de Capmany)-       Sants-Montjuïc
# 17                             METRO (L3) - TARRAGONA-             Eixample
# 18                   METRO (L3) - MUNDET (Can Marcet)-       Horta-Guinardó
# 19                   METRO (L3) - MUNDET (Can Marcet)-       Horta-Guinardó
# 20     METRO (L4) - EL MARESME-FÒRUM (C. del Maresme)-           Sant Martí
# 21                           METRO (L2) - UNIVERSITAT-             Eixample
# 22                      TRAMVIA (T5, T6) - ESPRONCEDA-           Sant Martí
# 23              TRAMVIA (T1,T2,T3) - AVINGUDA DE XILE-            Les Corts
# 24                     TRAMVIA (T1,T2,T3) - CAN RIGAL-                  NaN
# 25               TRAMVIA (T5) - ENCANTS DE SANT ADRIÀ-                  NaN
# 26                               TRAMVIA (T4) - FÒRUM-           Sant Martí
# 27           TRAMVIA (T4, T6) - ESTACIÓ DE SANT ADRIÀ-                  NaN
# 28                  TRAMVIA (T1,T2) - FONTSANTA-FATJÓ-                  NaN
# 29                     Estació Marítima INTERNACIONAL-                  NaN
# ..                                                 ...                  ...
# 621             METRO (L3) - DIAGONAL (Pg. de Gràcia)-             Eixample
# 622                      METRO (L9, L10) - LA SAGRERA-          Sant Andreu
# 623                            METRO (L5) - EL CARMEL-       Horta-Guinardó
# 624                              METRO (L2) - ENCANTS-           Sant Martí
# 625                             METRO (L1) - TORRASSA-                  NaN
# 626                 METRO (L1) - URQUINAONA (C. Bruc)-             Eixample
# 627                            METRO (L1) - CAN SERRA-                  NaN
# 628                        METRO (L1) - BARÓ DE VIVER-          Sant Andreu
# 629        METRO (L3) - POBLE SEC (Av. del Paral.lel)-       Sants-Montjuïc
# 630                     METRO (L3) - PLAÇA DEL CENTRE-            Les Corts
# 631       METRO (L3) - PENITENTS (C. d'Anna Piferrer)-               Gràcia
# 632                 FGC - MOLÍ NOU-CIUTAT COOPERATIVA-                  NaN
# 633                              FGC - CORNELLÀ-RIERA-                  NaN
# 634                      FGC - SANT VICENÇ DELS HORTS-                  NaN
# 635          TRAMVIA (T2) - CENTRE MIQUEL MARTÍ I POL-                  NaN
# 636                               METRO (L1) - URGELL-             Eixample
# 637           METRO (L1) - LA SAGRERA (Av. Meridiana)-          Sant Andreu
# 638                METRO (L1) - HOSPITAL DE BELLVITGE-                  NaN
# 639                        METRO (L1) - SANTA EULÀLIA-                  NaN
# 640                           METRO (L1) - MERCAT NOU-       Sants-Montjuïc
# 641                Tren AEROPORT - SANT ANDREU COMTAL-          Sant Andreu
# 642                            FGC (L6,L7) - PROVENÇA-             Eixample
# 643                      METRO (L1) - CLOT (C. Aragó)-           Sant Martí
# 644  METRO (L1) - MERCAT NOU (C. de la Riera de Tena)-       Sants-Montjuïc
# 645       METRO (L1) - ROCAFORT (Gv. Corts Catalanes)-             Eixample
# 646                              FGC - REINA ELISENDA-  Sarrià-Sant Gervasi
# 647                       Terminal Marítima E *Creuers       Sants-Montjuïc
# 648                       Terminal Marítima D *Creuers       Sants-Montjuïc
# 649                     FGC - LES TRES TORRES<center>-  Sarrià-Sant Gervasi
# 650              METRO (L3) - POBLE SEC (C. de Manso)-             Eixample
#
#                    Neighborhood.Name
# 0                             Sarrià
# 1             Sant Gervasi - Galvany
# 2                   la Trinitat Nova
# 3                   Ciutat Meridiana
# 4             la Dreta de l'Eixample
# 5             la Dreta de l'Eixample
# 6                             Sarrià
# 7                                NaN
# 8                   la Vall d'Hebron
# 9    l'Antiga Esquerra de l'Eixample
# 10                               NaN
# 11                     el Fort Pienc
# 12    la Nova Esquerra de l'Eixample
# 13            la Dreta de l'Eixample
# 14                             Horta
# 15                               NaN
# 16                             Sants
# 17    la Nova Esquerra de l'Eixample
# 18                  la Vall d'Hebron
# 19                  la Vall d'Hebron
# 20             el Besòs i el Maresme
# 21                       Sant Antoni
# 22           Provençals del Poblenou
# 23        la Maternitat i Sant Ramon
# 24                               NaN
# 25                               NaN
# 26             el Besòs i el Maresme
# 27                               NaN
# 28                               NaN
# 29                               NaN
# ..                               ...
# 621           la Dreta de l'Eixample
# 622                       la Sagrera
# 623                        el Carmel
# 624       el Camp de l'Arpa del Clot
# 625                              NaN
# 626           la Dreta de l'Eixample
# 627                              NaN
# 628                la Trinitat Vella
# 629                     el Poble-sec
# 630                        les Corts
# 631        Vallcarca i els Penitents
# 632                              NaN
# 633                              NaN
# 634                              NaN
# 635                              NaN
# 636                      Sant Antoni
# 637                       la Sagrera
# 638                              NaN
# 639                              NaN
# 640                            Sants
# 641                      Sant Andreu
# 642  l'Antiga Esquerra de l'Eixample
# 643                          el Clot
# 644                            Sants
# 645   la Nova Esquerra de l'Eixample
# 646                           Sarrià
# 647       la Marina del Prat Vermell
# 648       la Marina del Prat Vermell
# 649                  les Tres Torres
# 650                      Sant Antoni
#
# [651 rows x 7 columns]

# %%
transportscts = transports.groupby('District.Name').Transport.value_counts()
transportscts.to_frame().Transport
transportscts = transportscts.reset_index(level=["District.Name"])
transportscts = transportscts.rename(columns = {'Transport':'Count'})
transportscts.reset_index(level=0, inplace=True)
# Out:
# District.Name        Transport
# Ciutat Vella         Underground          22
#                      Cableway              2
#                      Maritime station      2
#                      RENFE                 1
# Eixample             Underground         103
#                      RENFE                 8
#                      Railway (FGC)         7
#                      Airport train         1
#                      Tram                  1
# Gràcia               Underground          15
#                      Railway (FGC)         2
# Horta-Guinardó       Underground          31
# Les Corts            Underground          15
#                      Tram                  9
# Nou Barris           Underground          38
#                      RENFE                 1
# Sant Andreu          Underground          36
#                      RENFE                 3
#                      Airport train         1
# Sant Martí           Underground          48
#                      Tram                 16
#                      Airport train         3
#                      RENFE                 3
# Sants-Montjuïc       Underground          39
#                      Maritime station      5
#                      Cableway              3
#                      Funicular             2
#                      Railway (FGC)         2
#                      Airport train         1
#                      RENFE                 1
# Sarrià-Sant Gervasi  Railway (FGC)        28
#                      Underground          25
#                      Tram                  9
#                      Funicular             4
# Name: Transport, dtype: int64

# %%
sns.catplot("District.Name","Count", "Transport", data = transportscts, kind = "bar", palette="muted",height=8.27, aspect=20.7/8.27)

# %%
buststopscts = busstops.groupby('District.Name').Transport.value_counts()
buststopscts.to_frame().Transport
buststopscts = buststopscts.reset_index(level=["District.Name"])
buststopscts = buststopscts.rename(columns = {'Transport':'Count'})
buststopscts.reset_index(level=0, inplace=True)

sns.catplot("District.Name","Count", "Transport", data = buststopscts, kind = "bar", palette="muted",height=8.27, aspect=20.7/8.27)
# Out:
# District.Name        Transport
# Ciutat Vella         Day bus stop        114
#                      Night bus stop       53
# Eixample             Day bus stop        245
#                      Night bus stop      154
#                      Airport bus stop      5
#                      Bus station           1
# Gràcia               Day bus stop        166
#                      Night bus stop       44
# Horta-Guinardó       Day bus stop        309
#                      Night bus stop       80
# Les Corts            Day bus stop        162
#                      Night bus stop       45
# Nou Barris           Day bus stop        254
#                      Night bus stop       76
# Sant Andreu          Day bus stop        161
#                      Night bus stop       66
#                      Bus station           1
# Sant Martí           Day bus stop        235
#                      Night bus stop      121
# Sants-Montjuïc       Day bus stop        334
#                      Night bus stop       78
#                      Airport bus stop      2
#                      Bus station           1
# Sarrià-Sant Gervasi  Day bus stop        333
#                      Night bus stop      106
# Name: Transport, dtype: int64

# %%
EixAcc= accidents[accidents["District Name"] == "Eixample"]
EixAccstrtcts = EixAcc.groupby('Neighborhood Name').Street.value_counts()
EixAccstrtcts.to_frame().Street
EixAccstrtcts = EixAccstrtcts.reset_index(level=["Neighborhood Name"])
EixAccstrtcts = EixAccstrtcts.rename(columns = {'Street':'Count'})
EixAccstrtcts.reset_index(level=0, inplace=True)
# Out:
# Neighborhood Name   Street
# Sant Antoni         Corts Catalanes                                       19
#                     Sepúlveda                                             10
#                     Comte d'Urgell                                         9
#                     Corts Catalanes / Vilamarí                             8
#                     Paral·lel                                              8
#                     Corts Catalanes / Viladomat                            6
#                     GV CORTS CATALANES                                     4
#                     SEPÚLVEDA                                              4
#                     Sepúlveda / Casanova                                   4
#                     Comte d'Urgell / Sepúlveda                             3
#                     Comte d'Urgell / Tamarit                               3
#                     Corts Catalanes / Calàbria                             3
#                     Corts Catalanes / Comte d'Urgell                       3
#                     Rocafort / Sepúlveda                                   3
#                     SEPÚLVEDA / Villarroel                                 3
#                     Sant Antoni                                            3
#                     Sant Pau                                               3
#                     Sepúlveda / Calàbria                                   3
#                     Sepúlveda / Viladomat                                  3
#                     Sepúlveda / Vilamarí                                   3
#                     Vilamarí / Paral·lel                                   3
#                     Calàbria                                               2
#                     Casanova / Corts Catalanes                             2
#                     Comte Borrell / Manso                                  2
#                     Comte d'Urgell / Floridablanca                         2
#                     Corts Catalanes / Aribau                               2
#                     Corts Catalanes / Comte Borrell                        2
#                     Corts Catalanes / Muntaner                             2
#                     Corts Catalanes / Universitat                          2
#                     Corts Catalanes / Villarroel                           2
#                                                                           ..
# la Sagrada Família  PADILLA / Aragó                                        1
#                     PADILLA / Indústria                                    1
#                     PROVENÇA / Castillejos                                 1
#                     PROVENÇA / Sicília                                     1
#                     Padilla / Aragó                                        1
#                     Padilla / Canadell                                     1
#                     Padilla / Mallorca                                     1
#                     Padilla / Provença                                     1
#                     Provença / Cartagena                                   1
#                     Provença / Dos de Maig                                 1
#                     Provença / Marina                                      1
#                     ROSSELLÓ / Padilla                                     1
#                     Rosselló / Dos de Maig                                 1
#                     Rosselló / Marina                                      1
#                     SARDENYA                                               1
#                     SICÍLIA / Mallorca                                     1
#                     ST ANTONI M CLARET                                     1
#                     ST ANTONI M CLARET / Dos de Maig                       1
#                     ST ANTONI M CLARET / Sardenya                          1
#                     Sant Antoni Maria Claret / Sardenya                    1
#                     Sardenya                                               1
#                     Sardenya / Aragó                                       1
#                     Sardenya / Diagonal                                    1
#                     Sardenya / Mallorca                                    1
#                     Sardenya / Sant Antoni Maria Claret                    1
#                     Sicília                                                1
#                     Sicília / Provença                                     1
#                     VALÈNCIA / Sicília                                     1
#                     València / Sicília                                     1
#                     valencia / Castillejos                                 1
# Name: Street, Length: 1190, dtype: int64

# %%
Ladretaacc = EixAccstrtcts[EixAccstrtcts["Neighborhood Name"] == "la Dreta de l'Eixample"]
# sns.catplot("Street","Count", data = Ladretaacc, kind = "bar", palette="muted",height=8.27, aspect=20.7/8.27)
Ladretaacc[Ladretaacc['Count'] == 41].Street
# Out:
# 459    Corts Catalanes                               ...
# Name: Street, dtype: object

# %%
unem2017 = unemployement[unemployement["Year"] == 2017]
unemdec2017 = unem2017[unem2017["Month"] == "December"]


unemcts = unemdec2017.groupby(["District Name","Gender"], as_index=False).sum()
unemcts2 = unemdec2017[unemdec2017["District Name"] == "Eixample"].groupby(["Neighborhood Name","Gender"], as_index=False).sum()

sns.catplot("District Name","Number", "Gender", data = unemcts, kind = "bar", palette="muted",height=8.27, aspect=20.7/8.27)
sns.catplot("Neighborhood Name","Number", "Gender", data = unemcts2, kind = "bar", palette="muted",height=8.27, aspect=20.7/8.27)

# %%
cortsacc = accidents[accidents['Street'].str.contains("Corts Catalanes")]
noncortsacc = accidents[~accidents['Street'].str.contains("Corts Catalanes")]

# %%
import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %%
crs = {'init': 'epsg:4326'}
cortsgeometry = [Point(xy) for xy in zip(cortsacc["Longitude"], cortsacc["Latitude"])]
noncortsgeometry =  [Point(xy) for xy in zip(noncortsacc["Longitude"], noncortsacc["Latitude"])]
allgeo =[Point(xy) for xy in zip(accidents["Longitude"], accidents["Latitude"])]
cortsgeo_acc = gpd.GeoDataFrame(cortsacc,
                          crs = crs,
                          geometry = cortsgeometry)

noncortsgeo_acc = gpd.GeoDataFrame(noncortsacc,
                          crs = crs,
                          geometry = noncortsgeometry)
allaccgeo = gpd.GeoDataFrame(accidents,
                          crs = crs,
                          geometry = allgeo)

# %%
street_map = gpd.read_file('BCN_Barri_ED50_SHP.shp')
street_map.crs
constreet_map = street_map.to_crs({'init': 'epsg:4326'})
# Out:
# {'ellps': 'intl', 'no_defs': True, 'proj': 'utm', 'units': 'm', 'zone': 31}

# %%
fig,ax = plt.subplots(figsize= (15,15))
constreet_map.plot(ax=ax, alpha = .4, color = "grey")
cortsgeo_acc[cortsgeo_acc["Vehicles involved"] == 2].plot(ax = ax, markersize = 20, color = "blue", marker = "o", label = "Accidents involving 2 cars")
cortsgeo_acc[cortsgeo_acc["Vehicles involved"] == 3].plot(ax = ax, markersize = 20, color = "red", marker = "^", label = "Accidents involving 3 cars")
cortsgeo_acc[cortsgeo_acc["Vehicles involved"] > 3].plot(ax = ax, markersize = 20, color = "white", marker = "^", label = "Accidents greater than 3 cars")
plt.legend(prop={'size':15})

# %%
fig,ax = plt.subplots(figsize= (15,15))
constreet_map.plot(ax=ax, alpha = .4, color = "grey")
noncortsgeo_acc[noncortsgeo_acc["Vehicles involved"] == 2].plot(ax = ax, markersize = 20, color = "blue", marker = "o", label = "Accidents involving 2 cars")
noncortsgeo_acc[noncortsgeo_acc["Vehicles involved"] == 3].plot(ax = ax, markersize = 20, color = "red", marker = "^", label = "Accidents involving 3 cars")
noncortsgeo_acc[noncortsgeo_acc["Vehicles involved"] > 3].plot(ax = ax, markersize = 20, color = "white", marker = "^", label = "Accidents greater than 3 cars")
plt.legend(prop={'size':15})

# %%
fig,ax = plt.subplots(figsize= (15,15))
constreet_map.plot(ax=ax, alpha = .4, color = "grey")
cortsgeo_acc[cortsgeo_acc["Part of the day"] == "Morning"].plot(ax = ax, markersize = 20, color = "blue", marker = "o", label = "M")
cortsgeo_acc[cortsgeo_acc["Part of the day"] == "Afternoon"].plot(ax = ax, markersize = 20, color = "red", marker = "o", label = "A")
cortsgeo_acc[cortsgeo_acc["Part of the day"] == "Night"].plot(ax = ax, markersize = 20, color = "white", marker = "o", label = "N")
plt.legend(prop={'size':15})

# %%
fig,ax = plt.subplots(figsize= (15,15))
constreet_map.plot(ax=ax, alpha = .4, color = "grey")
allaccgeo[allaccgeo["Vehicles involved"] == 2].plot(ax = ax, markersize = 20, color = "blue", marker = "o", label = "Accidents involving 2 cars")
allaccgeo[allaccgeo["Vehicles involved"] == 3].plot(ax = ax, markersize = 20, color = "red", marker = "^", label = "Accidents involving 3 cars")
allaccgeo[allaccgeo["Vehicles involved"] > 3].plot(ax = ax, markersize = 20, color = "white", marker = "^", label = "Accidents greater than 3 cars")
plt.legend(prop={'size':15})

# %%
janacc = allaccgeo[allaccgeo["Hour"] == 20]
# Out:
#   File "<ipython-input-34-15b7a4cacc95>", line 1
#     janacc = allaccgeo[allaccgeo["Hour"] == 20] && allaccgeo[allaccgeo["Weekday"] == "Friday"]
#                                                  ^
# SyntaxError: invalid syntax

# %%
fig,ax = plt.subplots(figsize= (15,15))
constreet_map.plot(ax=ax, alpha = .4, color = "grey")
janacc[janacc["Vehicles involved"] == 2].plot(ax = ax, markersize = 20, color = "blue", marker = "o", label = "Accidents involving 2 cars")
janacc[janacc["Vehicles involved"] == 3].plot(ax = ax, markersize = 20, color = "red", marker = "^", label = "Accidents involving 3 cars")
janacc[janacc["Vehicles involved"] > 3].plot(ax = ax, markersize = 20, color = "white", marker = "^", label = "Accidents greater than 3 cars")
plt.legend(prop={'size':15})
